# %% [markdown]
# Code for Model finetuning on labelled dataset.
# Finetuning pre-trained "distilbert-base-uncased" on combined_dataset for sentiment analysis.
# Finetuning pre-trained KeyBART on combined_dataset for Trends Extractions.

# %%
# !pip install transformers datasets scikit-learn
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.2)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 8.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.9 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 10.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.8 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %% [markdown]
# Here we are extracting sentences, sentiments, keywords and trends from labelled dataset and preparing training and testing data.

# %%
import json
import random
from sklearn.model_selection import train_test_split

# Load your labeled dataset
dataset_path = "/content/combined_dataset.json"
with open(dataset_path, "r") as file:
    data = json.load(file)

# Extract sentences, sentiments, and trends
sentences = [item["sentence"] for item in data]
sentiments = [item["sentiment"] for item in data]
keywords = [item["keywords"] for item in data]
trends = [item["trends"] for item in data]

# Flatten sentences 
flat_sentences = [" ".join(sentence_group) for sentence_group in sentences]

# Split into train and test
train_texts, test_texts, train_sentiments, test_sentiments, train_trends, test_trends = train_test_split(
    flat_sentences, sentiments, trends, test_size=0.2, random_state=42
)

# %% [markdown]
# Code for Finetuning DistilBERT for sentiment analysis on training dataset.

# %%
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
import torch

# Tokenization
sentiment_tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

# Prepare datasets
train_dataset = Dataset.from_dict({
    "text": train_texts,
    "labels": [1 if sentiment == "positive" else 0 for sentiment in train_sentiments]
})
test_dataset = Dataset.from_dict({
    "text": test_texts,
    "labels": [1 if sentiment == "positive" else 0 for sentiment in test_sentiments]
})

def tokenize_function(examples):
    return sentiment_tokenizer(examples["text"], truncation=True, padding=True, max_length=256)

train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Model setup
sentiment_model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased")

# Training arguments
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    num_train_epochs=5,
    weight_decay=0.01
)

# Trainer
trainer = Trainer(
    model=sentiment_model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=sentiment_tokenizer
)

# Fine-tune the model
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Map:   0%|          | 0/4564 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1141 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-4-3a139819daf7>:40: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241129_034052-1z1bfbgp</code>
# Syncing run <strong><a href='https://wandb.ai/mayuri-j-kate-dalhousie-university/huggingface/runs/1z1bfbgp' target="_blank">./results</a></strong> to <a href='https://wandb.ai/mayuri-j-kate-dalhousie-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mayuri-j-kate-dalhousie-university/huggingface' target="_blank">https://wandb.ai/mayuri-j-kate-dalhousie-university/huggingface</a>
#  View run at <a href='https://wandb.ai/mayuri-j-kate-dalhousie-university/huggingface/runs/1z1bfbgp' target="_blank">https://wandb.ai/mayuri-j-kate-dalhousie-university/huggingface/runs/1z1bfbgp</a>
#     <div>
#
#       <progress value='2855' max='2855' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2855/2855 10:22, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.421600</td>
#       <td>0.324980</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.267200</td>
#       <td>0.399453</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.129600</td>
#       <td>0.672810</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.057900</td>
#       <td>0.703585</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.026200</td>
#       <td>0.710535</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2855, training_loss=0.16015489347761858, metrics={'train_runtime': 651.4273, 'train_samples_per_second': 35.031, 'train_steps_per_second': 4.383, 'total_flos': 1511326760675616.0, 'train_loss': 0.16015489347761858, 'epoch': 5.0})

# %% [markdown]
# Evaluating model on testing dataset and printing evaluation metrics

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# Predictions
predictions = trainer.predict(test_dataset)
preds = torch.argmax(torch.tensor(predictions.predictions), axis=1).numpy()

# Calculate metrics
accuracy = accuracy_score(test_dataset["labels"], preds)
precision, recall, f1, _ = precision_recall_fscore_support(test_dataset["labels"], preds, average="binary")

print(f"Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}")
# Out:
# Accuracy: 0.8729, Precision: 0.9003, Recall: 0.8913, F1 Score: 0.8958

# %% [markdown]
# Now finetuning KeyBART model on testing data

# %%
from transformers import BartForConditionalGeneration, BartTokenizer, TrainingArguments, Trainer
from datasets import Dataset
import torch

# Load tokenizer and model
trends_tokenizer = BartTokenizer.from_pretrained("ml6team/keyphrase-generation-keybart-inspec")
trends_model = BartForConditionalGeneration.from_pretrained("ml6team/keyphrase-generation-keybart-inspec")

def preprocess_trends_data(texts, targets):
    inputs = [f"extract keyphrases: {text}" for text in texts]
    # Tokenize and convert to lists for Dataset.from_dict
    input_encodings = trends_tokenizer(inputs, max_length=512, truncation=True, padding=True)
    target_encodings = trends_tokenizer(targets, max_length=512, truncation=True, padding=True)
    return {
        "input_ids": input_encodings.input_ids,
        "attention_mask": input_encodings.attention_mask,
        "labels": target_encodings.input_ids,
    }

# Preprocess data
train_data = preprocess_trends_data(train_texts, ["; ".join(trend) for trend in train_trends])
test_data = preprocess_trends_data(test_texts, ["; ".join(trend) for trend in test_trends])

# Create datasets using Dataset.from_dict
train_dataset = Dataset.from_dict(train_data)
test_dataset = Dataset.from_dict(test_data)

# Fine-tuning
training_args = TrainingArguments(
    output_dir="./trends_results",
    evaluation_strategy="epoch",
    learning_rate=3e-5,
    per_device_train_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=trends_model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    processing_class=trends_tokenizer
)

# Fine-tune
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# <ipython-input-8-cad2637d8a41>:38: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='3423' max='3423' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3423/3423 59:22, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.844000</td>
#       <td>0.942207</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.609500</td>
#       <td>0.888445</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.467600</td>
#       <td>0.869039</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2817: UserWarning: Moving the following attributes in the config to the generation config: {'early_stopping': True, 'num_beams': 4, 'no_repeat_ngram_size': 3}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# TrainOutput(global_step=3423, training_loss=0.7979888782283907, metrics={'train_runtime': 3565.2682, 'train_samples_per_second': 3.84, 'train_steps_per_second': 0.96, 'total_flos': 1.4835998106058752e+16, 'train_loss': 0.7979888782283907, 'epoch': 3.0})

# %% [markdown]
# Here we are printing few samples from test dataset along with predicted trends by finetuned model and actual trends present in labelled dataset.
# We are saving the output printed in "finteuned_samples_generated_trends.txt" file, to get evaluation metrics.

# %%
# %env PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# Generate predictions
test_input_ids = test_dataset["input_ids"]  # Get input_ids from test_dataset
batch_size = 4  
predicted_trends = []
for i in range(0, len(test_input_ids), batch_size):
    # Convert the list of lists to a PyTorch tensor
    batch_input_ids = torch.tensor(test_input_ids[i : i + batch_size])
    # Now move it to the device
    batch_input_ids = batch_input_ids.to(trends_model.device)
    outputs = trends_model.generate(
        batch_input_ids, max_length=50, num_beams=5, early_stopping=True
    )
    predicted_trends.extend(
        [trends_tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
    )

# Compare predicted vs actual
for i, (pred, actual) in enumerate(zip(predicted_trends, test_trends)):
    print(f"Sample {i}:")
    print(f"  Predicted: {pred}")
    print(f"  Actual: {'; '.join(actual)}")
    print("-" * 20)
# Out:
# env: PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
# Sample 0:
#   Predicted: collection ;  center ;  brilliant ;  one ;  diamonds
#   Actual: center; collection; come; diamonds; brilliance; one; spinning
# --------------------
# Sample 1:
#   Predicted: yet ;  cut ;  start ;  nine ;  source ;  diamonds ;  major
#   Actual: nine; cut; yet; start; underground; finished; red
# --------------------
# Sample 2:
#   Predicted: controlled ;  de ;  beers ;  historically ;  important ;  look ;  pricing
#   Actual: controlled; primarily; diamond; organization; de; historically; important
# --------------------
# Sample 3:
#   Predicted: things ;  working ;  always ;  us ;  know ;  take ;  complex
#   Actual: things; always; working; us; take; easy; hone
# --------------------
# Sample 4:
#   Predicted: know ;  stores ;  united ;  year ;  million ;  selling ;  hundred
#   Actual: know; stores; working; united; top; year; selling
# --------------------
# Sample 5:
#   Predicted: rich ;  world ;  hurting ;  actually ;  got ;  answer ;  back
#   Actual: question; think; answer; world; rich; get; got
# --------------------
# Sample 6:
#   Predicted: selling ;  even ;  want ;  sure ;  synthetic ;  alternatives ;  diamonds
#   Actual: even; selling; require; reports; know; want; sure
# --------------------
# Sample 7:
#   Predicted: years ;  every ;  industry ;  evolution ;  wide ;  takes ;  time
#   Actual: every; years; industry; anything; takes; cycle; ca
# --------------------
# Sample 8:
#   Predicted: see ;  today ;  partners ;  term ;  play ;  years ;  one
#   Actual: years; term; reason; play; partners; ones; today
# --------------------
# Sample 9:
#   Predicted: little ;  getting ;  emotional ;  today ;  recording ;  studio ;  podcast
#   Actual: today; studio; recording; podcast; altogether; little; getting
# --------------------
# Sample 10:
#   Predicted: sales ;  holidays ;  whatever ;  would ;  number ;  honest ;  numerology
#   Actual: sales; holidays; would; able; new; uptick; except
# --------------------
# Sample 11:
#   Predicted: years ;  white ;  stores ;  forward
#   Actual: like; years; walked; two; stores; everything; fast
# --------------------
# Sample 12:
#   Predicted: still ;  inflation ;  us ;  rate ;  like ;  target ;  really
#   Actual: inflation; still; us; things; really; priced; high
# --------------------
# Sample 13:
#   Predicted: actually ;  recovered ;  la ;  roan ;  photograph ;  de ;  one
#   Actual: recovered; la; actually; november; sede; de; rona
# --------------------
# Sample 14:
#   Predicted: sort ;  worries ;  list
#   Actual: time; machine; actually; worries; sort; list; adds
# --------------------
# Sample 15:
#   Predicted: much ;  perception ;  believe ;  consumer ;  wrong
#   Actual: much; allow; ethics; happen; justified; believe; consumer
# --------------------
# Sample 16:
#   Predicted: collection ;  think ;  working ;  tache ;  queen ;  kalahari ;  stone ;  full
#   Actual: collection; think; acquired; full; around; us; stone
# --------------------
# Sample 17:
#   Predicted: india ;  guess ;  firstly ;  wedding ;  thing ;  outside
#   Actual: india; wedding; thing; people; outside; market; guess
# --------------------
# Sample 18:
#   Predicted: never ;  reason ;  give ;  work ;  simply ;  want ;  touch
#   Actual: never; reason; give; work; want; touch; simply
# --------------------
# Sample 19:
#   Predicted: rappaport ;  follow ;  get ;  visit ;  diamond ;  discussions ;  industry
#   Actual: rappaport; follow; get; visit; us; diamond; discussions
# --------------------
# Sample 20:
#   Predicted: wrong ;  whatever ;  laundering ;  money
#   Actual: wrong; whatever; product; money; looting; laundering; banks
# --------------------
# Sample 21:
#   Predicted: something ;  convince ;  somebody ;  buy ;  put ;  tag ;  know
#   Actual: incredible; could; put; price; tag; know; buy
# --------------------
# Sample 22:
#   Predicted: came ;  ukraine ;  quite ;  bit ;  grown ;  material ;  higher
#   Actual: came; quite; bit; grown; ukraine; always; market
# --------------------
# Sample 23:
#   Predicted: like ;  different ;  us ;  million ;  acronyms
#   Actual: like; different; right; people; million; us; acronyms
# --------------------
# Sample 24:
#   Predicted: designing ;  diamonds ;  jewelry ;  consumer ;  current
#   Actual: jewelry; diamonds; designing; opportunity; offer; newly; consumer
# --------------------
# Sample 25:
#   Predicted: podcast ;  well ;  us ;  guests
#   Actual: podcast; industry; quizzing; people; one; love; learning
# --------------------
# Sample 26:
#   Predicted: actually ;  walmart ;  fair ;  pricing ;  go ;  best ;  diamonds
#   Actual: walmart; actually; recommend; pricing; marco; lab; grown
# --------------------
# Sample 27:
#   Predicted: world ;  prices ;  affected ;  also
#   Actual: world; prices; really; question; interesting; spoke; like
# --------------------
# Sample 28:
#   Predicted: time ;  hardened ;  worse ;  arms ;  race ;  better ;  better
#   Actual: time; hardened; ca; creating; everything; worse; arms
# --------------------
# Sample 29:
#   Predicted: natural ;  even ;  lab ;  dare ;  stones ;  far ;  today
#   Actual: natural; lab; stones; dare; even; origin; unfortunately
# --------------------
# Sample 30:
#   Predicted: russia ;  origin ;  word ;  significant ;  meaning ;  excludes ;  significant
#   Actual: origin; russia; transformed; substantially; significant; phrase; outside
# --------------------
# Sample 31:
#   Predicted: impact ;  also ;  showcasing ;  solutions ;  would ;  body ;  interoperability
#   Actual: solutions; impact; also; showcasing; luxury; adopting; advantages
# --------------------
# Sample 32:
#   Predicted: volume ;  saying ;  extra ;  natural ;  getting
#   Actual: correctly; extra; get; gia; going; longer; yes
# --------------------
# Sample 33:
#   Predicted: want ;  think ;  job ;  play ;  supply ;  manufacture ;  retail
#   Actual: want; supply; retail; produce; manufacture; think; play
# --------------------
# Sample 34:
#   Predicted: diamonds ;  grown ;  us ;  happens ;  china
#   Actual: diamonds; lab; years; later; china; ends; experience
# --------------------
# Sample 35:
#   Predicted: three ;  michaels ;  lee ;  correct ;  brothers
#   Actual: three; michaels; lee; father; correct; brothers
# --------------------
# Sample 36:
#   Predicted: jewelry ;  piece ;  also ;  year ;  product ;  categories
#   Actual: jewelry; piece; also; continue; go; components; course
# --------------------
# Sample 37:
#   Predicted: sometimes ;  necessarily ;  online ;  social ;  stores ;  media ;  online
#   Actual: sometimes; necessarily; found; asking; stores; social; online
# --------------------
# Sample 38:
#   Predicted: value ;  solution ;  needs ;  chain ;  ultimately ;  cross ;  ultimately
#   Actual: value; ultimately; solution; needs; cross; chain
# --------------------
# Sample 39:
#   Predicted: rough ;  think ;  inventories ;  polished ;  month ;  drop ;  time ;  similar ;  drop
#   Actual: inventories; think; month; rough; polished; drop; take
# --------------------
# Sample 40:
#   Predicted: things ;  certain ;  kravitz ;  things ;  even ;  group ;  discussions
#   Actual: havi; opinion; explained; things; discussions; even; people
# --------------------
# Sample 41:
#   Predicted: job ;  car ;  parking ;  office
#   Actual: job; car; control; could; drive; lot; parking
# --------------------
# Sample 42:
#   Predicted: synthetic ;  diamonds ;  recent ;  collection ;  rubies ;  examples
#   Actual: synthetic; diamonds; part; tell; aware; others; donated
# --------------------
# Sample 43:
#   Predicted: diamonds ;  increase ;  sales ;  said ;  demand ;  mind ;  sort
#   Actual: diamonds; sales; demand; increase; said; carat; larger
# --------------------
# Sample 44:
#   Predicted: world ;  mood ;  section ;  luce
#   Actual: world; sky; section; mood; luce; generally; wow
# --------------------
# Sample 45:
#   Predicted: rappaport ;  follow ;  subscribe ;  get ;  future ;  twitter ;  linkedin
#   Actual: rappaport; follow; subscribe; get; future; twitter; linkedin
# --------------------
# Sample 46:
#   Predicted: sustainability ;  located ;  wobbly ;  things ;  suppliers ;  think ;  products ;  still
#   Actual: sustainability; located; wobbly; think; things; suppliers; still
# --------------------
# Sample 47:
#   Predicted: exactly ;  know ;  something ;  us ;  glad ;  things ;  interesting
#   Actual: know; exactly; us; something; came; things; kinds
# --------------------
# Sample 48:
#   Predicted: would ;  store ;  love ;  hit ;  cops ;  point ;  hard
#   Actual: would; store; love; hit; point; hard; cops
# --------------------
# Sample 49:
#   Predicted: saying ;  flexibility ;  past ;  thinking ;  price ;  fixed ;  surat
#   Actual: saying; flexibility; surat; fact; everything; thinking; price
# --------------------
# Sample 50:
#   Predicted: supply ;  though ;  goods ;  concentrate ;  quality ;  go ;  big
#   Actual: though; supply; quality; goods; go; concentrate; commercial
# --------------------
# Sample 51:
#   Predicted: said ;  one ;  shout ;  first ;  answer ;  first
#   Actual: said; one; first; answer; shout
# --------------------
# Sample 52:
#   Predicted:  Authenticity ;  yes ;  think ;  sharing ;  personality ;  recently ;  caught
#   Actual: authentic; recently; caught; attention; anything; yes; sonia
# --------------------
# Sample 53:
#   Predicted: think ;  lab ;  really ;  driven ;  selling
#   Actual: think; really; marketing; lab; unfortunate; trying; selling
# --------------------
# Sample 54:
#   Predicted: think ;  moment ;  probably ;  pandemic ;  retailers
#   Actual: think; retailers; going; suspicion; probably; previous; pandemic
# --------------------
# Sample 55:
#   Predicted: emamples ;  us ;  share ;  like
#   Actual: examples; us; share; like; stories; love; know
# --------------------
# Sample 56:
#   Predicted: looking ;  world ;  population ;  movement ;  type ;  people ;  normal
#   Actual: looking; lives; show; rhythm; people; normal; world
# --------------------
# Sample 57:
#   Predicted: diamonds ;  really ;  cer ;  used ;  experts ;  footprint
#   Actual: diamonds; footprint; analyze; cer; used; experts; really
# --------------------
# Sample 58:
#   Predicted: timing ;  alluded ;  maybe ;  point ;  understand
#   Actual: understand; timing; point; maybe; looks; little; important
# --------------------
# Sample 59:
#   Predicted: equipment ;  working ;  university ;  level ;  expensive ;  best ;  diamonds
#   Actual: equipment; actual; based; contrary; determination; working; best
# --------------------
# Sample 60:
#   Predicted: like ;  computer ;  create
#   Actual: like; create; computer
# --------------------
# Sample 61:
#   Predicted: went ;  review ;  sure ;  ring
#   Actual: husband; came; back; sure; ring; review; negative
# --------------------
# Sample 62:
#   Predicted: retail ;  spent ;  rather ;  worth ;  based ;  still ;  big
#   Actual: worth; still; spent; retail; rather; big; based
# --------------------
# Sample 63:
#   Predicted: two ;  contrasting ;  cygnet ;  faring ;  performances
#   Actual: cygnet; develop; direct; two; contrasting; ways; caused
# --------------------
# Sample 64:
#   Predicted: go ;  straight ;  dance ;  whatever ;  us
#   Actual: straight; go; got; dance; whatever; want; us
# --------------------
# Sample 65:
#   Predicted: things ;  started ;  one ;  observation ;  beers ;  working ;  retailers
#   Actual: journey; company; de; industry; initially; issues; working
# --------------------
# Sample 66:
#   Predicted: take ;  comes ;  apart
#   Actual: take; going; comes; apart; along
# --------------------
# Sample 67:
#   Predicted: waste ;  nature ;  becomes ;  animal ;  part
#   Actual: waste; nature; produce; lives; need; never; newly
# --------------------
# Sample 68:
#   Predicted: right ;  hope ;  one ;  men ;  find
#   Actual: right; one; men; hope; find
# --------------------
# Sample 69:
#   Predicted: time ;  booth ;  lot ;  like ;  retailers
#   Actual: lot; booth; time; like; year; next; see
# --------------------
# Sample 70:
#   Predicted: bc ;  start ;  people ;  shock ;  listening
#   Actual: bc; start; talons; shells; shock; victoria; museum
# --------------------
# Sample 71:
#   Predicted: industry ;  think ;  young ;  understand ;  course
#   Actual: going; important; whoever; think; industry; india; comes
# --------------------
# Sample 72:
#   Predicted: done ;  think ;  options ;  really ;  jewelry ;  recent ;  like
#   Actual: done; think; really; options; jewelry; years; see
# --------------------
# Sample 73:
#   Predicted: would ;  much ;  money ;  understand ;  natural
#   Actual: take; would; think; natural; much; money; years
# --------------------
# Sample 74:
#   Predicted: know ;  prompted ;  father
#   Actual: remains; policy; company; prompted; know; father
# --------------------
# Sample 75:
#   Predicted: video ;  diamond ;  world ;  trusted ;  network
#   Actual: video; diamond; network; brought; largest; world; comments
# --------------------
# Sample 76:
#   Predicted: started ;  name ;  much ;  collection ;  business ;  believe ;  ability
#   Actual: started; nothing; name; much; made; happen; entire
# --------------------
# Sample 77:
#   Predicted: everything ;  give ;  reach ;  like ;  brands ;  quality ;  investing
#   Actual: give; everything; reach; quality; like; investing; brands
# --------------------
# Sample 78:
#   Predicted:
#   Actual: number; let; go; back
# --------------------
# Sample 79:
#   Predicted: third ;  system ;  cost ;  systems ;  producing ;  carrots ;  twice
#   Actual: system; third; cost; systems; twice; producing; carrots
# --------------------
# Sample 80:
#   Predicted: project ;  wanted ;  representation ;  hundred ;  women
#   Actual: project; know; discuss; women; trying; wanted; representation
# --------------------
# Sample 81:
#   Predicted: diamond ;  many ;  years ;  happens ;  industry ;  feeds
#   Actual: diamond; years; many; level; goes; excitement; industry
# --------------------
# Sample 82:
#   Predicted: diamond ;  natural ;  something ;  see ;  people ;  value ;  live
#   Actual: diamond; natural; value; something; see; people; visually
# --------------------
# Sample 83:
#   Predicted: sales ;  antwerp ;  huge ;  rough ;  believe ;  strong ;  connection
#   Actual: sales; rough; big; believe; huge; advantage; diamond
# --------------------
# Sample 84:
#   Predicted: industry ;  bit ;  good ;  opportunity ;  really ;  know
#   Actual: industry; bit; good; sort; decided; like; area
# --------------------
# Sample 85:
#   Predicted: Kelly ;  good ;  person ;  according ;  lvmh ;  spending ;  percentage ;  know
#   Actual: kelly; spending; revenue; percentage; ones; marketing; person
# --------------------
# Sample 86:
#   Predicted:
#   Actual:
# --------------------
# Sample 87:
#   Predicted: say ;  know ;  consumers ;  talk ;  topic ;  often ;  kind
#   Actual: say; know; topic; talk; sustainability; often; kind
# --------------------
# Sample 88:
#   Predicted: case ;  open ;  would ;  difficult ;  circumstances ;  job ;  much
#   Actual: would; much; job; difficult; open; key; inside
# --------------------
# Sample 89:
#   Predicted: hope ;  america ;  china ;  know ;  communism ;  bunch ;  diamond ;  well
#   Actual: na; gon; america; hope; china; well; bunch
# --------------------
# Sample 90:
#   Predicted: think ;  year ;  strong ;  overall ;  past ;  strong
#   Actual: think; year; much; last; half; years; strong
# --------------------
# Sample 91:
#   Predicted: retail ;  couple ;  retail ;  generations ;  family ;  retail
#   Actual: industry; get; experience; retail; generations; family; couple
# --------------------
# Sample 92:
#   Predicted: people ;  would ;  delayed ;  make ;  little
#   Actual: would; sound; pessimistic; period; make; people; spoke
# --------------------
# Sample 93:
#   Predicted: campaign ;  particularly ;  complex ;  could ;  designed ;  definitely ;  canva
#   Actual: particularly; complex; campaign; designed; definitely; could; canva
# --------------------
# Sample 94:
#   Predicted: diamond ;  time ;  launched ;  jewelry ;  quite
#   Actual: diamond; also; another; jewelry; launched; time; quite
# --------------------
# Sample 95:
#   Predicted: someone ;  long ;  interviewed ;  years ;  jck ;  back ;  interviewed
#   Actual: long; next; name; love; someone; years; jck
# --------------------
# Sample 96:
#   Predicted: goods ;  trading ;  center ;  would ;  basically ;  polished ;  sort
#   Actual: goods; center; polished; trading; would; brought; call
# --------------------
# Sample 97:
#   Predicted: timé ;  winston ;  stamped ;  thing ;  distributed ;  see
#   Actual: winston; timé; piece; thing; tells; stamped; distributed
# --------------------
# Sample 98:
#   Predicted: business ;  continue ;  opportunity ;  working ;  brothers ;  father ;  working
#   Actual: business; working; father; brothers; alongside; opportunity; great
# --------------------
# Sample 99:
#   Predicted: diamond ;  represents ;  romance ;  think ;  example
#   Actual: think; example; brilliant; botswana; romance; represents; eternity
# --------------------
# Sample 100:
#   Predicted: turn ;  market ;  sell ;  report ;  funny ;  hphts ;  cvds
#   Actual: market; sell; turn; hphts; report; cvds; funny
# --------------------
# Sample 101:
#   Predicted: heart ;  cool ;  zimu ;  recently ;  saw ;  shape
#   Actual: heart; cool; zimu; brooch; called; shape; saw
# --------------------
# Sample 102:
#   Predicted: right ;  et ;  cetera ;  greener ;  less ;  humanity ;  cruel
#   Actual: right; et; cetera; synthetic; something; share; market
# --------------------
# Sample 103:
#   Predicted: known ;  guest ;  victim ;  also ;  senior ;  analyst ;  dear
#   Actual: victim; senior; kravitz; friend; dear; called; avi
# --------------------
# Sample 104:
#   Predicted: maybe ;  fit ;  good ;  think ;  correct ;  Gutfeel ;  industry
#   Actual: might; maybe; good; fit; think; gutfeel; correct
# --------------------
# Sample 105:
#   Predicted: category ;  jewelry ;  years ;  fine
#   Actual: category; years; two; took; take; jewelry; fine
# --------------------
# Sample 106:
#   Predicted: really ;  like ;  one ;  software ;  mind
#   Actual: software; really; one; company; mind; better; get
# --------------------
# Sample 107:
#   Predicted: term ;  work ;  could ;  like ;  employees ;  internal ;  address
#   Actual: like; could; term; work; address; also; suppliers
# --------------------
# Sample 108:
#   Predicted: know ;  started ;  week ;  said ;  remember ;  pandemic ;  first
#   Actual: started; know; years; week; said; three; like
# --------------------
# Sample 109:
#   Predicted: say ;  pleasure ;  every ;  course ;  put ;  jewelry ;  end
#   Actual: slide; says; put; pleasure; need; jewelry; every
# --------------------
# Sample 110:
#   Predicted: want ;  prison ;  nothing ;  hard
#   Actual: throwing; start; licenses; want; prison; nothing; cop
# --------------------
# Sample 111:
#   Predicted: much ;  nonsense ;  years ;  synthetic ;  manufacturers ;  past ;  hear
#   Actual: nonsense; much; hear; years; various; synthetic; spewed
# --------------------
# Sample 112:
#   Predicted: went ;  see ;  talked ;  life ;  two ;  stores ;  hard
#   Actual: went; talked; works; two; stores; passionate; hard
# --------------------
# Sample 113:
#   Predicted: want ;  mall ;  take ;  store ;  run ;  take
#   Actual: want; take; store; run; mall
# --------------------
# Sample 114:
#   Predicted: beers ;  de ;  facing ;  market ;  industry ;  company ;  bradley
#   Actual: de; beers; facing; market; industry; bruce; company
# --------------------
# Sample 115:
#   Predicted: something ;  watch ;  use ;  brands ;  make
#   Actual: something; store; people; watch; sales; rolex; patek
# --------------------
# Sample 116:
#   Predicted: wanted ;  business ;  see ;  worked ;  generation ;  obviously ;  first
#   Actual: wanted; see; worked; started; obviously; mean; growing
# --------------------
# Sample 117:
#   Predicted: know ;  going ;  proposal ;  signet ;  dating
#   Actual: know; going; proposed; anyone; sort; scientific; quite
# --------------------
# Sample 118:
#   Predicted:
#   Actual: networking; course; business
# --------------------
# Sample 119:
#   Predicted: compparative ;  plastics ;  example ;  meaning ;  waste ;  precious ;  would
#   Actual: example; meaning; compare; plastics; know; recycling; complicated
# --------------------
# Sample 120:
#   Predicted: wanted ;  people ;  particularly ;  pandemic ;  go ;  day ;  retail ;  therapy ;  end
#   Actual: therapy; retail; end; think; wanted; people; particularly
# --------------------
# Sample 121:
#   Predicted: world ;  exceptional ;  seen ;  affected ;  years ;  think ;  results
#   Actual: world; seen; affected; exceptional; last; years; think
# --------------------
# Sample 122:
#   Predicted: covid ;  things ;  grow ;  always ;  love ;  see ;  oriented
#   Actual: things; see; sun; stumbled; researching; oriented; love
# --------------------
# Sample 123:
#   Predicted: view ;  respect ;  consumers ;  industry ;  perception
#   Actual: industry; view; respect; unethical; perception; mean; among
# --------------------
# Sample 124:
#   Predicted: diamond ;  companies ;  smaller ;  trade ;  want ;  stop ;  certification ;  source
#   Actual: diamond; want; stop; companies; trade; smaller; challenge
# --------------------
# Sample 125:
#   Predicted: like ;  definitely ;  vegas ;  liked ;  report
#   Actual: like; vegas; liked; hanging; definitely; report; market
# --------------------
# Sample 126:
#   Predicted: way ;  melee ;  say ;  different
#   Actual: fact; july; labs; coming; must; moment; mean
# --------------------
# Sample 127:
#   Predicted: think ;  used ;  things ;  quite ;  population
#   Actual: think; planet; even; inhabitants; everything; less; actually
# --------------------
# Sample 128:
#   Predicted: one ;  based ;  focused ;  online ;  sustainability
#   Actual: sustainability; setting; online; focused; community; one; based
# --------------------
# Sample 129:
#   Predicted: plus ;  would ;  america ;  high ;  selling
#   Actual: plus; would; similar; selling; jewelers; independent; high
# --------------------
# Sample 130:
#   Predicted: wishing ;  weeks ;  see ;  meaningful ;  new ;  year ;  buy ;  solution
#   Actual: year; wishing; weeks; two; solution; sell; right
# --------------------
# Sample 131:
#   Predicted: said ;  mission ;  left ;  aborting ;  back ;  decided
#   Actual: decided; came; back; said; mission; left; aborting
# --------------------
# Sample 132:
#   Predicted: open ;  still ;  reaction ;  podcast
#   Actual: open; still; see; reaction; speaking; really; humorous
# --------------------
# Sample 133:
#   Predicted: covid ;  like ;  years ;  think ;  two ;  invite ;  someone
#   Actual: like; covid; happened; felt; really; kong; hong
# --------------------
# Sample 134:
#   Predicted: chance ;  half ;  win ;  think ;  points
#   Actual: chance; half; win; catch; think; sonia; points
# --------------------
# Sample 135:
#   Predicted: many ;  times ;  think ;  occasion ;  government
#   Actual: many; times; parts; occasion; think; government; idea
# --------------------
# Sample 136:
#   Predicted:
#   Actual:
# --------------------
# Sample 137:
#   Predicted: money ;  want ;  mining ;  license ;  would ;  renegotiating ;  two
#   Actual: want; money; license; mining; spending; arapa; renegotiating
# --------------------
# Sample 138:
#   Predicted: try ;  realistic ;  let ;  room ;  people ;  lot ;  smart
#   Actual: try; realistic; let; think; likes; anyone; smart
# --------------------
# Sample 139:
#   Predicted: claims ;  certain ;  would ;  blanket ;  easy
#   Actual: claims; certain; yeah; ways; way; people; misleading
# --------------------
# Sample 140:
#   Predicted: expensive ;  carats ;  lot ;  manufacturing ;  gossier ;  three ;  stone
#   Actual: expensive; three; manufacturing; lot; gossier; stone; polish
# --------------------
# Sample 141:
#   Predicted: way ;  talking ;  try ;  keep ;  clients ;  power ;  try
#   Actual: highly; diamonds; cyclical; become; way; try; talking
# --------------------
# Sample 142:
#   Predicted: place ;  go ;  think ;  destination ;  landmark ;  new ;  name
#   Actual: think; go; place; landmark; destination; art; artwork
# --------------------
# Sample 143:
#   Predicted: someone ;  concern ;  know ;  specific ;  intellectual ;  property ;  intellectual
#   Actual: way; strongly; feel; specific; someone; property; know
# --------------------
# Sample 144:
#   Predicted: distribution ;  diamonds ;  problems ;  thought ;  russian ;  sanctions ;  issue
#   Actual: distribution; talk; synthetic; sanctions; russian; okay; issue
# --------------------
# Sample 145:
#   Predicted: work ;  people ;  understand ;  get ;  places ;  today ;  understand
#   Actual: initiatives; completely; hk; impressed; done; reservations; work
# --------------------
# Sample 146:
#   Predicted: changes ;  making ;  instigating ;  yeah ;  started ;  procedure ;  soon
#   Actual: changes; things; yeah; took; time; consultation; get
# --------------------
# Sample 147:
#   Predicted: vegetation ;  firstly ;  governments ;  use ;  things ;  later ;  questions
#   Actual: veto; use; turned; things; saying; originally; later
# --------------------
# Sample 148:
#   Predicted: diamonds ;  grown ;  would ;  treatment ;  market ;  as-grown ;  alleged
#   Actual: diamonds; color; gone; grow; grown; metallic; typically
# --------------------
# Sample 149:
#   Predicted: complete ;  highly ;  craftsmen ;  new ;  able ;  identity ;  gradually
#   Actual: craftsmen; new; able; highly; complete; identity; focus
# --------------------
# Sample 150:
#   Predicted: year ;  gave ;  million ;  earlier ;  spending ;  past ;  past
#   Actual: experiences; indicate; consumers; prediction; inflation; jewelry; background
# --------------------
# Sample 151:
#   Predicted: like ;  industry ;  luxury ;  also ;  talked ;  pay ;  macro
#   Actual: like; industry; luxury; talked; pay; also; look
# --------------------
# Sample 152:
#   Predicted: fcc ;  ways ;  enforcing ;  claims ;  genuine ;  ensuring
#   Actual: ways; ftc; advertising; also; enforcing; claims; ensuring
# --------------------
# Sample 153:
#   Predicted: would ;  retailers ;  certainly ;  buying ;  us ;  greatly ;  cause
#   Actual: comparatively; high; interest; rates; levels; indian; try
# --------------------
# Sample 154:
#   Predicted: years ;  really ;  botswana ;  community ;  five ;  done ;  understanding
#   Actual: really; years; botswana; done; five; community; understanding
# --------------------
# Sample 155:
#   Predicted: people ;  bourse ;  really ;  couple ;  surprised ;  women ;  everywhere
#   Actual: people; really; couple; bourse; everywhere; granted; women
# --------------------
# Sample 156:
#   Predicted: also ;  help ;  think ;  work ;  specific ;  scope ;  people
#   Actual: background; come; cooperation; different; international; also; help
# --------------------
# Sample 157:
#   Predicted: one ;  yeah ;  think ;  things ;  ever
#   Actual: one; growth; attention; challenges; members; growing; phenomenal
# --------------------
# Sample 158:
#   Predicted: platform ;  diamonds ;  well ;  polished ;  going ;  year ;  modest
#   Actual: platform; diamonds; year; really; scope; phase; next
# --------------------
# Sample 159:
#   Predicted: jewelry ;  fine ;  lot ;  seen ;  actually ;  lab ;  grown
#   Actual: jewelry; fine; actually; seen; lab; grown; lot
# --------------------
# Sample 160:
#   Predicted: melee ;  rough ;  dilemma ;  would ;  working ;  opportunity
#   Actual: melee; rough; dilemma; explain; give; like; working
# --------------------
# Sample 161:
#   Predicted: video ;  creators ;  concept
#   Actual: really; cool; actually; video; creators; concept; came
# --------------------
# Sample 162:
#   Predicted: issues ;  way ;  supplying ;  consumer ;  forever
#   Actual: issues; always; developments; shocks; seems; recent; need
# --------------------
# Sample 163:
#   Predicted: happen ;  rappaport ;  year ;  holidays ;  everybody ;  subscribe ;  get ;  future
#   Actual: happy; rappaport; get; forget; future; group; facebook
# --------------------
# Sample 164:
#   Predicted: used ;  problems ;  well ;  hey ;  came ;  says ;  found
#   Actual: would; goes; says; problems; well; hey; used
# --------------------
# Sample 165:
#   Predicted: price ;  important ;  would ;  pillars ;  marketing
#   Actual: price; important; led; economics; carat; like; cost
# --------------------
# Sample 166:
#   Predicted: old ;  holidays ;  working ;  much ;  relying
#   Actual: holidays; old; working; even; back; going; talking
# --------------------
# Sample 167:
#   Predicted: turkish ;  lot ;  dealings
#   Actual: turkish; market; lot; dealings
# --------------------
# Sample 168:
#   Predicted: would ;  auction ;  love ;  piece ;  like ;  style ;  investigate
#   Actual: style; like; would; piece; period; love; jewelry
# --------------------
# Sample 169:
#   Predicted: expensive ;  area ;  extremely ;  tell ;  part ;  magic ;  tell
#   Actual: area; expensive; extremely; around; chinese; many; magic
# --------------------
# Sample 170:
#   Predicted: us ;  lots ;  tried ;  tone ;  important
#   Actual: lots; left; us; tried; tone; set; important
# --------------------
# Sample 171:
#   Predicted: well ;  selling ;  sapphires ;  especially ;  think ;  people
#   Actual: well; selling; gems; think; people; market; lot
# --------------------
# Sample 172:
#   Predicted: market ;  maybe ;  bit ;  half ;  figure ;  selling ;  accumulators ;  flexibility
#   Actual: market; selling; flexibility; accumulators; trade; stronger; stock
# --------------------
# Sample 173:
#   Predicted: put ;  experience ;  personal ;  narrative ;  maybe ;  way ;  trying
#   Actual: personal; experience; put; planned; council; early; diamond
# --------------------
# Sample 174:
#   Predicted: get ;  gift ;  also ;  anniversary ;  graduation
#   Actual: get; gift; also; graduation; anniversary; pictures; boxes
# --------------------
# Sample 175:
#   Predicted: think ;  enough ;  orange ;  juice ;  natural ;  know ;  ways
#   Actual: think; enough; juice; orange; natural; know; spread
# --------------------
# Sample 176:
#   Predicted: years ;  already ;  busy ;  several ;  pipeline ;  different ;  pipeline
#   Actual: geopolitical; forward; true; also; climate; definitely; years
# --------------------
# Sample 177:
#   Predicted: end ;  think ;  na ;  end ;  would ;  discount ;  Thanksgiving
#   Actual: think; gon; na; end; different; elements; many
# --------------------
# Sample 178:
#   Predicted: instagram ;  setting ;  independent ;  bit ;  sort
#   Actual: setting; bit; independent; instagram; working; company; dealer
# --------------------
# Sample 179:
#   Predicted: really ;  said ;  like ;  work ;  dad ;  rest ;  life
#   Actual: really; demon; said; like; first; see; know
# --------------------
# Sample 180:
#   Predicted: stock ;  memo ;  go ;  show
#   Actual: stock; memo; go; show; access; website; jeweler
# --------------------
# Sample 181:
#   Predicted: look ;  never ;  sell ;  image ;  like ;  somebody ;  website
#   Actual: look; sell; putting; website; somebody; seen; never
# --------------------
# Sample 182:
#   Predicted: us ;  stopped ;  takes ;  leads ;  better ;  believe ;  chutzpah
#   Actual: worth; never; us; takes; tell; sobolewski; king
# --------------------
# Sample 183:
#   Predicted: polish ;  started ;  manufacturing ;  rough ;  world ;  sales ;  created
#   Actual: polish; started; world; quite; created; net; sales
# --------------------
# Sample 184:
#   Predicted: diamond ;  floor ;  space ;  million ;  multi-storey ;  square ;  floor
#   Actual: diamond; goods; across; square; space; several; covers
# --------------------
# Sample 185:
#   Predicted: really ;  people ;  mine ;  large ;  know
#   Actual: people; really; tell; one; happy; slick; operation
# --------------------
# Sample 186:
#   Predicted: really ;  rotation ;  know ;  like ;  design ;  somehow ;  absorbing
#   Actual: much; jewelry; somehow; art; design; embedded; grew
# --------------------
# Sample 187:
#   Predicted: think ;  works ;  mind ;  way ;  streams ;  kind ;  positioning
#   Actual: think; white; within; two; streams; puts; works
# --------------------
# Sample 188:
#   Predicted: want ;  personalized ;  us ;  usually ;  come ;  people ;  noticed
#   Actual: season; important; holiday; want; usually; us; significant
# --------------------
# Sample 189:
#   Predicted: business ;  becoming ;  natural ;  consequence ;  settled ;  kind ;  country
#   Actual: business; becoming; people; natural; kind; accountants; become
# --------------------
# Sample 190:
#   Predicted: industry ;  know ;  would ;  asking ;  really ;  something ;  people
#   Actual: industry; know; would; really; first; going; love
# --------------------
# Sample 191:
#   Predicted: blessed ;  worked ;  port ;  long ;  feel ;  man ;  wild
#   Actual: blessed; worked; wild; really; old; man; port
# --------------------
# Sample 192:
#   Predicted: well ;  job ;  simplifying ;  quite ;  easy ;  system ;  standard
#   Actual: well; simplifying; done; good; job; making; understandable
# --------------------
# Sample 193:
#   Predicted: facts ;  front ;  want ;  make ;  decision ;  put ;  consumer
#   Actual: facts; front; thing; ways; real; put; look
# --------------------
# Sample 194:
#   Predicted: diamonds ;  russia ;  years ;  war ;  ukraine ;  speak
#   Actual: diamonds; russian; russia; years; beginning; war; discussion
# --------------------
# Sample 195:
#   Predicted: traditional ;  work ;  patterns ;  designers
#   Actual: traditional; patterns; yuval; last; banak; became; ceramics
# --------------------
# Sample 196:
#   Predicted: prices ;  mellie ;  natural ;  falling ;  garbage ;  diamond
#   Actual: prices; mellie; natural; going; beers; first; year
# --------------------
# Sample 197:
#   Predicted: understand ;  kind ;  data ;  think ;  bit
#   Actual: understand; data; think; kind; excel; junkie; get
# --------------------
# Sample 198:
#   Predicted: one ;  people ;  tended ;  go ;  bill ;  go
#   Actual: tended; people; one; go; bill
# --------------------
# Sample 199:
#   Predicted: idea ;  sanctions ;  greater ;  enforcement ;  expect ;  trade ;  strong
#   Actual: idea; strong; really; point; coming; money; trade
# --------------------
# Sample 200:
#   Predicted: watch ;  market ;  voice ;  prestigious ;  view ;  power ;  journalism
#   Actual: market; watches; watch; voice; owning; journalism; power
# --------------------
# Sample 201:
#   Predicted: well ;  independent ;  know ;  lot ;  jewelers ;  right ;  stores
#   Actual: stores; right; jewelry; changed; well; lot; know
# --------------------
# Sample 202:
#   Predicted: year ;  said ;  happy ;  years ;  started
#   Actual: year; bit; end; years; business; started; since
# --------------------
# Sample 203:
#   Predicted: scale ;  solution ;  obviously ;  work ;  lack
#   Actual: solution; scale; work; lack; industry; said; important
# --------------------
# Sample 204:
#   Predicted: bourse ;  indian ;  back ;  ploughing ;  steam ;  companies
#   Actual: bourse; indian; back; lacks; small; companies; reporting
# --------------------
# Sample 205:
#   Predicted: really ;  rest ;  know ;  factories
#   Actual: really; one; know; day; factories; gives; go
# --------------------
# Sample 206:
#   Predicted: terms ;  results ;  poor ;  operations ;  competition ;  anybody ;  hear
#   Actual: results; poor; terms; operations; say; inflation; hear
# --------------------
# Sample 207:
#   Predicted: back ;  get ;  like ;  make
#   Actual: like; back; get; make; issue; want; phenomenon
# --------------------
# Sample 208:
#   Predicted: australia ;  australina ;  chose ;  stores ;  questions ;  month
#   Actual: australia; stores; chose; brisbane; told; going; ask
# --------------------
# Sample 209:
#   Predicted: synthetic ;  say ;  putzes ;  robert ;  unfair ;  natural
#   Actual: synthetic; deceptive; describe; genuine; yuts; oh; calling
# --------------------
# Sample 210:
#   Predicted: planning ;  cycle ;  supply ;  siteholders ;  importantly
#   Actual: planning; sites; larger; expect; supply; siteholders; importantly
# --------------------
# Sample 211:
#   Predicted: brand ;  name ;  think ;  realisation ;  industry
#   Actual: brand; think; realisation; one; name; industry; coming
# --------------------
# Sample 212:
#   Predicted: york ;  new ;  conference ;  September ;  made
#   Actual: york; new; september; made; conference; go; everyone
# --------------------
# Sample 213:
#   Predicted: diamond ;  center ;  manufacturing ;  india ;  go ;  spend ;  opportunity
#   Actual: center; diamond; go; india; manufacturing; main; actually
# --------------------
# Sample 214:
#   Predicted: lot ;  really ;  buzz ;  gadot ;  ambassador
#   Actual: lot; think; buzz; really; created; nice; ambassador
# --------------------
# Sample 215:
#   Predicted: war ;  people ;  want ;  happy
#   Actual: despite; emotions; cities; larger; theater; situation; especially
# --------------------
# Sample 216:
#   Predicted: youtube ;  linkedin ;  follow ;  twitter ;  facebook
#   Actual: subscribe; get; future; forget; youtube; twitter; rappaport
# --------------------
# Sample 217:
#   Predicted: technology ;  separation ;  detection ;  improvement
#   Actual: technology; show; minute; enough; detect; separation; improve
# --------------------
# Sample 218:
#   Predicted: years ;  best ;  make ;  sure
#   Actual: make; best; years; sure; industry; lot; describe
# --------------------
# Sample 219:
#   Predicted: want ;  topic ;  hot ;  next ;  women
#   Actual: women; want; traders; miners; interviewing; fasciners; topic
# --------------------
# Sample 220:
#   Predicted: diamond ;  export ;  free ;  see ;  legal ;  requirement ;  antwerp
#   Actual: trading; single; requires; requirement; export; diamond; see
# --------------------
# Sample 221:
#   Predicted: keep ;  going ;  trade ;  independent ;  time ;  always ;  chain
#   Actual: trade; going; independent; keep; well; said; looking
# --------------------
# Sample 222:
#   Predicted: process ;  agree ;  reach ;  members ;  ever
#   Actual: agree; process; taken; astounding; debated; find; long
# --------------------
# Sample 223:
#   Predicted: rules ;  blanket ;  general ;  judged
#   Actual: rules; way; judged; general; blanket
# --------------------
# Sample 224:
#   Predicted: diamond ;  organization ;  world ;  young ;  tears ;  part ;  founded
#   Actual: diamond; organization; one; contributor; experts; great; also
# --------------------
# Sample 225:
#   Predicted: botswana ;  easy ;  think ;  create ;  around ;  specific ;  diamonds
#   Actual: coming; easier; bit; deptswana; aggregation; happens; little
# --------------------
# Sample 226:
#   Predicted: make ;  world ;  think ;  dealers ;  relative ;  say ;  assumptions
#   Actual: make; world; say; data; loyal; get; easy
# --------------------
# Sample 227:
#   Predicted: want ;  store ;  synthetic ;  walks
#   Actual: wants; walks; synthetic; store; guy; diamonds; buy
# --------------------
# Sample 228:
#   Predicted: want ;  engagement ;  pay ;  actually ;  willing ;  overpay ;  lab
#   Actual: engagement; actually; want; pay; clients; grown; willing
# --------------------
# Sample 229:
#   Predicted: years ;  see ;  going
#   Actual: years; see; next; going; five; anything
# --------------------
# Sample 230:
#   Predicted: collection ;  something ;  carry ;  people ;  like
#   Actual: something; collection; like; carry; donors; people; long
# --------------------
# Sample 231:
#   Predicted: deal ;  diamonds ;  emeralds ;  rubies ;  like ;  platinum
#   Actual: deal; diamonds; made; sapphires; rubies; gold; platinum
# --------------------
# Sample 232:
#   Predicted: different ;  appraiser ;  term ;  really ;  value ;  broad ;  jewelry
#   Actual: different; whether; fair; term; really; placing; piece
# --------------------
# Sample 233:
#   Predicted: wear ;  cotton ;  world ;  think ;  compare ;  would ;  industry
#   Actual: cotton; would; world; think; industry; industries; grow
# --------------------
# Sample 234:
#   Predicted: reasons ;  rebel ;  rights ;  governments ;  change ;  definition ;  human
#   Actual: rights; rebel; rather; human; groups; governments; discussions
# --------------------
# Sample 235:
#   Predicted: think ;  compelling ;  story ;  things ;  unique ;  running ;  peak
#   Actual: diamonds; production; unique; discover; finite; journey; running
# --------------------
# Sample 236:
#   Predicted: would ;  like ;  finger ;  taught
#   Actual: would; like; wow; looking; knowing; know; instagram
# --------------------
# Sample 237:
#   Predicted: industry ;  see ;  watches ;  unbranded ;  wonder ;  moving
#   Actual: industry; see; wonder; extent; moving; transpired; watches
# --------------------
# Sample 238:
#   Predicted: watch ;  without ;  name ;  anybody ;  generic ;  one ;  anywhere
#   Actual: watch; one; generic; anywhere; without; name; anybody
# --------------------
# Sample 239:
#   Predicted: kind ;  educated ;  buyer ;  something
#   Actual: kind; documentation; assumed; ask; buyer; educated; would
# --------------------
# Sample 240:
#   Predicted: day ;  go ;  factory ;  sure ;  everything ;  going ;  factory
#   Actual: go; day; well; twice; sure; everything; factory
# --------------------
# Sample 241:
#   Predicted: sent ;  love ;  send ;  vinina ;  edited ;  produced ;  pikolk
#   Actual: vanina; produced; pikolk; edited
# --------------------
# Sample 242:
#   Predicted: message ;  managing ;  naseem ;  waliam
#   Actual: william; whatsapp; send; naseem; message; managing; lahari
# --------------------
# Sample 243:
#   Predicted: diamonds ;  today ;  back ;  discussing ;  dazzling ;  market ;  rachel
#   Actual: today; discussing; successfully; rachel; plenty; market; jewelry
# --------------------
# Sample 244:
#   Predicted: actually ;  year ;  together ;  sustainability ;  really
#   Actual: actually; together; ago; ceo; really; sustainability; year
# --------------------
# Sample 245:
#   Predicted: category ;  marketing ;  diamonds ;  india ;  greater ;  opportunity ;  opportunity
#   Actual: marketing; diamonds; category; india; opportunity; interest; share
# --------------------
# Sample 246:
#   Predicted: business ;  like ;  know ;  chickens ;  roasting ;  fox ;  guard
#   Actual: like; know; business; owns; maybe; african; company
# --------------------
# Sample 247:
#   Predicted: hope ;  podcast ;  really ;  get ;  chance ;  happy ;  soon
#   Actual: soon; really; podcast; hope; happy; get; chance
# --------------------
# Sample 248:
#   Predicted: youtube ;  weekly ;  watch ;  videos
#   Actual: youtube; weekly; watch; videos; market; invite; comment
# --------------------
# Sample 249:
#   Predicted: going ;  vast ;  material ;  majority ;  see ;  mill ;  year
#   Actual: going; material; see; vast; majority; date; fabulous
# --------------------
# Sample 250:
#   Predicted: think ;  years ;  things ;  one ;  brands ;  last ;  see
#   Actual: still; see; part; years; think; things; one
# --------------------
# Sample 251:
#   Predicted: pavilion ;  something ;  hall ;  world ;  loose ;  lab
#   Actual: pavilion; something; hall; world; loose; lab; grow
# --------------------
# Sample 252:
#   Predicted: kids ;  trust ;  dad ;  tell ;  us ;  one ;  reasons
#   Actual: kids; know; us; trust; tell; reasons; one
# --------------------
# Sample 253:
#   Predicted: talk ;  course ;  also ;  demand ;  amazing ;  stories ;  come
#   Actual: course; talk; stories; come; nice; jewel; favorite
# --------------------
# Sample 254:
#   Predicted: top ;  luxury ;  brands ;  firm ;  top ;  turnover ;  done
#   Actual: top; luxury; focused; firm; brands; steadfast; link
# --------------------
# Sample 255:
#   Predicted: years ;  could ;  something ;  monetary ;  long
#   Actual: could; years; relatives; long; monetary; back; value
# --------------------
# Sample 256:
#   Predicted: number ;  britain ;  constantly ;  miners ;  sales ;  around
#   Actual: around; miners; sales; constantly; alros; one; number
# --------------------
# Sample 257:
#   Predicted: dad ;  purchase ;  college ;  guy ;  home
#   Actual: dad; college; us; home; purchase; money; jewelry
# --------------------
# Sample 258:
#   Predicted: conditions ;  working ;  maybe ;  precarious ;  focus
#   Actual: conditions; working; much; dangerous; designer; sourcing; used
# --------------------
# Sample 259:
#   Predicted: things ;  work ;  consumers ;  change ;  keen ;  journey ;  adapt
#   Actual: things; consumers; see; react; need; learn; keen
# --------------------
# Sample 260:
#   Predicted: fire ;  Oval ;  shapes ;  princess ;  three
#   Actual: fire; us; come; hot; long; oval; cushion
# --------------------
# Sample 261:
#   Predicted: sure ;  looked ;  way ;  understood ;  really
#   Actual: training; going; example; way; understood; standards; set
# --------------------
# Sample 262:
#   Predicted: diamond ;  india ;  market ;  jewelry ;  indian ;  company ;  unique
#   Actual: diamond; india; devansh; market; venus; partner; guest
# --------------------
# Sample 263:
#   Predicted: us ;  government ;  particularly ;  considerations
#   Actual: us; government; mommy; governments; good; daddy; bad
# --------------------
# Sample 264:
#   Predicted: diamonds ;  season ;  holiday ;  still ;  recorded ;  conversation ;  going
#   Actual: diamonds; season; consumer; insurance; holiday; still; conversation
# --------------------
# Sample 265:
#   Predicted: know ;  say ;  saying ;  wonderful ;  place ;  administrative ;  overhead
#   Actual: know; life; allow; bit; done; flexibility; wonderful
# --------------------
# Sample 266:
#   Predicted: licensees ;  throwing ;  attack ;  cop ;  comes
#   Actual: throwing; start; licenses; cop; comes; attack; anxiety
# --------------------
# Sample 267:
#   Predicted: us ;  work ;  clarity ;  information ;  shipped
#   Actual: us; work; system; shipped; made; know; information
# --------------------
# Sample 268:
#   Predicted: rappaport ;  diamond ;  podcast ;  host ;  friedman ;  joshua
#   Actual: dubai; dmcc; centre; joshua; host; friedman; welcome
# --------------------
# Sample 269:
#   Predicted: low ;  clarity ;  color ;  demand ;  india
#   Actual: clarity; low; colors; changed; demand; clients; factor
# --------------------
# Sample 270:
#   Predicted: topic ;  important ;  reading ;  podcast ;  enjoyed
#   Actual: topic; lot; information; reading; podcast; hope; everyone
# --------------------
# Sample 271:
#   Predicted: diamonds ;  public ;  also ;  process ;  believe
#   Actual: diamonds; discussion; public; within; process; believe; also
# --------------------
# Sample 272:
#   Predicted: would ;  ruby ;  probably ;  think ;  rich
#   Actual: would; thought; think; rich; ruby; probably; go
# --------------------
# Sample 273:
#   Predicted: tommy ;  right ;  name ;  richmond ;  incredible ;  really
#   Actual: tommy; right; richmond; name; really; incredible; able
# --------------------
# Sample 274:
#   Predicted: know ;  looking ;  lot ;  people ;  would ;  actually ;  trying
#   Actual: looking; lot; know; actually; committed; people; would
# --------------------
# Sample 275:
#   Predicted: store ;  brick ;  mortar ;  store ;  going ;  mind ;  million
#   Actual: believe; stone; sell; see; mind; million; store
# --------------------
# Sample 276:
#   Predicted: connected ;  jewelry ;  people ;  like ;  regular
#   Actual: jewelry; connected; people; beautiful; concern; like; gemstone
# --------------------
# Sample 277:
#   Predicted: entervin ;  companies ;  diamond ;  british ;  emphilipp ;  board ;  directors ;  transparency ;  board
#   Actual: companies; belgian; diamond; epstein; ceo; related; initial
# --------------------
# Sample 278:
#   Predicted:
#   Actual:
# --------------------
# Sample 279:
#   Predicted: stores ;  would ;  year ;  predict ;  absorb
#   Actual: absorb; changes; forecast; forward; stores; year; predicted
# --------------------
# Sample 280:
#   Predicted: podcast ;  welcome ;  diamond ;  rappaport
#   Actual: podcast; welcome; diamond; rappaport; brought; consumers; trade
# --------------------
# Sample 281:
#   Predicted: market ;  partly ;  welcome ;  rappaport
#   Actual: partly; usual; reasons; demand; diamond; market; rappaport
# --------------------
# Sample 282:
#   Predicted: us ;  time ;  lutz ;  podcast ;  sharing ;  thank ;  much
#   Actual: us; time; thank; sharing; view; industry; hearing
# --------------------
# Sample 283:
#   Predicted: would ;  veered ;  partnership ;  costs ;  public-private
#   Actual: yearly; participate; forward; membership; much; veered; costs
# --------------------
# Sample 284:
#   Predicted: us ;  made ;  jealous ;  books ;  think
#   Actual: writing; thanks; thank; much; us; think; made
# --------------------
# Sample 285:
#   Predicted: angela ;  harry ;  podcast ;  say ;  longtime ;  winston
#   Actual: winston; say; podcast; longtime; hedges; harry; great
# --------------------
# Sample 286:
#   Predicted: gold ;  lots ;  years ;  like ;  innovation
#   Actual: gold; lots; come; pure; products; past; like
# --------------------
# Sample 287:
#   Predicted:
#   Actual:
# --------------------
# Sample 288:
#   Predicted: solution ;  traceability ;  lot ;  phrase ;  technology
#   Actual: solution; yet; would; information; traceability; technology; problem
# --------------------
# Sample 289:
#   Predicted: business ;  would ;  healthy ;  say ;  watch ;  michaels ;  lee ;  would
#   Actual: business; tell; stores; market; would; watch; say
# --------------------
# Sample 290:
# ...
#   Actual: diamond; live; money; natural; turnover; even; fast
# --------------------
# Sample 1044:
#   Predicted: little ;  think ;  totally ;  used ;  try
#   Actual: think; little; bit; looser; maybe; pr; rather
# --------------------
# Sample 1045:
#   Predicted: recycled ;  think ;  term ;  repurposed ;  waste ;  energy ;  yeah ;  level ;  like
#   Actual: think; recycled; waste; energy; use; yeah; like
# --------------------
# Sample 1046:
#   Predicted: saw ;  opportunity ;  working ;  whole ;  spent ;  mentioned ;  natural
#   Actual: working; whole; spent; natural; mentioned; life; diamonds
# --------------------
# Sample 1047:
#   Predicted: walk ;  window ;  seeing ;  goods ;  jkp ;  used ;  store
#   Actual: walked; walk; used; store; shopping; past; window
# --------------------
# Sample 1048:
#   Predicted: rappaport ;  analysis ;  team ;  effort ;  also
#   Actual: team; analysis; rappaport; editorial; written; package; webinar
# --------------------
# Sample 1049:
#   Predicted: conversation ;  pleasure ;  really ;  value ;  hope ;  add ;  good
#   Actual: conversation; value; really; pleasure; hope; good; add
# --------------------
# Sample 1050:
#   Predicted: know ;  diamond ;  whole ;  think ;  like ;  forever ;  two
#   Actual: know; diamond; story; different; behind; whole; think
# --------------------
# Sample 1051:
#   Predicted: twitter ;  follow ;  wrappperport ;  group ;  facebook ;  linkedin
#   Actual: wrapperport; twitter; linkedin; instagram; group; follow; facebook
# --------------------
# Sample 1052:
#   Predicted: market ;  goods ;  come ;  people ;  hundreds ;  buy ;  actually
#   Actual: goods; come; market; people; values; recycled; get
# --------------------
# Sample 1053:
#   Predicted: year ;  next ;  want ;  shorts ;  really ;  week ;  like
#   Actual: next; really; want; year; shorts; week; going
# --------------------
# Sample 1054:
#   Predicted: wish ;  strong ;  designers ;  precious ;  today ;  take ;  jewelry
#   Actual: olga; foundation; grateful; history; jewelry; wish; best
# --------------------
# Sample 1055:
#   Predicted: think ;  matter ;  really ;  good ;  chasing
#   Actual: somewhere; may; go; truth; yes; pennies; margins
# --------------------
# Sample 1056:
#   Predicted: inflation ;  job ;  next ;  rate ;  year
#   Actual: inflation; rate; done; job; fed; year; next
# --------------------
# Sample 1057:
#   Predicted: something ;  say ;  wanted ;  something ;  wanted
#   Actual: wanted; something; say; result; historically; gems; accurate
# --------------------
# Sample 1058:
#   Predicted: big ;  lot ;  world ;  demand ;  market ;  coming ;  part
#   Actual: lot; big; market; coming; see; clarity; trends
# --------------------
# Sample 1059:
#   Predicted: customers ;  world ;  memo ;  comes ;  office
#   Actual: customers; almost; comes; countries; actually; cornell; reading
# --------------------
# Sample 1060:
#   Predicted: people ;  around ;  year ;  see ;  give ;  lot ;  already
#   Actual: people; around; year; see; tell; live; lot
# --------------------
# Sample 1061:
#   Predicted: campaign ;  really ;  think ;  celebrity
#   Actual: campaign; well; think; really; celebrity; hit; use
# --------------------
# Sample 1062:
#   Predicted: diamonds ;  touched ;  even ;  companies ;  one ;  personally
#   Actual: diamonds; carat; touched; companies; personally; one; never
# --------------------
# Sample 1063:
#   Predicted: years ;  past ;  notoriety ;  gained ;  lot ;  talking ;  one
#   Actual: one; us; put; years; past; couple; features
# --------------------
# Sample 1064:
#   Predicted: israel ;  well ;  worried ;  world ;  jewelry
#   Actual: would; nervous; anxious; community; israel; given; think
# --------------------
# Sample 1065:
#   Predicted: role ;  diamond ;  industry ;  start ;  asking
#   Actual: role; industry; diamond; start; company; asking
# --------------------
# Sample 1066:
#   Predicted: stone ;  necessarily ;  cut ;  mean
#   Actual: stone; think; significance; route; notoriety; need; size
# --------------------
# Sample 1067:
#   Predicted: customer ;  jeweler ;  providing ;  paperwork ;  correct ;  establishing ;  value
#   Actual: jeweler; customer; like; advise; hand; help; well
# --------------------
# Sample 1068:
#   Predicted: value ;  proposition ;  think ;  retailer ;  good ;  imagine ;  one
#   Actual: think; value; proposition; lab; one; grown; imagine
# --------------------
# Sample 1069:
#   Predicted: online ;  reports ;  overall ;  ad hoc
#   Actual: website; transparency; reports; put; overall; online; ones
# --------------------
# Sample 1070:
#   Predicted: natural ;  see ;  think ;  diamond ;  generally ;  lab ;  outliers
#   Actual: natural; see; diamond; think; like; grown; outliers
# --------------------
# Sample 1071:
#   Predicted: goods ;  mixed ;  way ;  jewelry ;  evil
#   Actual: goods; way; together; mixers; mixed; jewelry; evil
# --------------------
# Sample 1072:
#   Predicted: clients ;  look ;  day ;  industry ;  love ;  end
#   Actual: look; clients; current; deal; always; end; day
# --------------------
# Sample 1073:
#   Predicted: wonderful ;  anyone ;  wants ;  wide ;  results ;  learn
#   Actual: jewelry; wide; range; places; results; learn; wonderful
# --------------------
# Sample 1074:
#   Predicted: lab-grown ;  year ;  weak ;  think ;  timing ;  natural ;  buying
#   Actual: year; although; analysis; buying; byproduct; convenient; diamonds
# --------------------
# Sample 1075:
#   Predicted: learning ;  really ;  know ;  works ;  think ;  people ;  want
#   Actual: really; learning; know; works; want; think; people
# --------------------
# Sample 1076:
#   Predicted: think ;  thing ;  well ;  gave ;  source ;  many ;  think
#   Actual: well; knowing; important; really; podcast; people; passionate
# --------------------
# Sample 1077:
#   Predicted: see ;  issue ;  way ;  felt ;  asked
#   Actual: issue; see; way; ladbroin; argument; artificial; asked
# --------------------
# Sample 1078:
#   Predicted: think ;  years ;  turned ;  knew ;  even ;  turned
#   Actual: years; turned; think; old; knew; even
# --------------------
# Sample 1079:
#   Predicted: like ;  targeting ;  space ;  something
#   Actual: unique; truly; stones; specialized; something; price; white
# --------------------
# Sample 1080:
#   Predicted: want ;  choose ;  around ;  provenance ;  moment ;  traceability ;  believe
#   Actual: want; choose; around; keep; share; platform; participant
# --------------------
# Sample 1081:
#   Predicted: go ;  going ;  partners ;  always ;  set ;  yeah ;  part
#   Actual: going; anglo; bad; beers; decision; go; yeah
# --------------------
# Sample 1082:
#   Predicted: would ;  world ;  knew ;  pieces ;  jewelry ;  one ;  important
#   Actual: would; pieces; important; loved; one; knew; said
# --------------------
# Sample 1083:
#   Predicted: change ;  company ;  dig ;  little ;  today
#   Actual: company; change; today; means; little; beyond; prospectus
# --------------------
# Sample 1084:
#   Predicted: part ;  contemporary ;  jewelry
#   Actual: really; pleased; involved; part; jewelry; curating; contemporary
# --------------------
# Sample 1085:
#   Predicted: back ;  us ;  trip ;  started
#   Actual: back; welcome; podcast; present; past; links; hope
# --------------------
# Sample 1086:
#   Predicted: strong ;  work ;  partnerships ;  diamond
#   Actual: strong; relationships; reason; work; today; partnerships; diamond
# --------------------
# Sample 1087:
#   Predicted: consumers ;  us ;  want ;  trend ;  seen
#   Actual: consumers; big; diamonds; want; economy; high; interest
# --------------------
# Sample 1088:
#   Predicted: one ;  model ;  like ;  sold ;  blocky
#   Actual: one; resin; model; like; sold; carat; blocky
# --------------------
# Sample 1089:
#   Predicted: yet ;  bottom ;  reached ;  price ;  continue ;  drop ;  little
#   Actual: price; going; drop; continue; yet; reached; bottom
# --------------------
# Sample 1090:
#   Predicted: free ;  state ;  talked ;  demand
#   Actual: talked; state; nft; giving; free; emerged; diamonds
# --------------------
# Sample 1091:
#   Predicted: valentine ;  day ;  bad ;  lesson ;  reinforces ;  jewelry
#   Actual: valentine; one; reinforces; podcast; lesson; jewelry; important
# --------------------
# Sample 1092:
#   Predicted: crime ;  currently ;  terms ;  retail ;  seen
#   Actual: crime; aspirational; comes; day; end; upsurge; currently
# --------------------
# Sample 1093:
#   Predicted: shows ;  sort ;  selling ;  watches
#   Actual: name; john; watches; sort; shows; selling; secondhand
# --------------------
# Sample 1094:
#   Predicted: able ;  access ;  retail ;  media ;  data ;  make ;  two ;  operating
#   Actual: retail; able; media; make; data; access; two
# --------------------
# Sample 1095:
#   Predicted:
#   Actual:
# --------------------
# Sample 1096:
#   Predicted: work ;  scale ;  always ;  thinking ;  platform ;  works ;  industry
#   Actual: works; thinking; scale; quite; platform; industry; fundamentally
# --------------------
# Sample 1097:
#   Predicted: working ;  years ;  things ;  women ;  covid ;  still ;  even
#   Actual: hardly; even; ca; years; working; women; things
# --------------------
# Sample 1098:
#   Predicted: way ;  decided ;  primarily ;  learnings
#   Actual: way; primarily; learnings; going; focus; digital; decided
# --------------------
# Sample 1099:
#   Predicted: still ;  level ;  strong ;  foundation ;  covid ;  said ;  global
#   Actual: still; sort; said; remains; market; mainstay; like
# --------------------
# Sample 1100:
#   Predicted: would ;  premium ;  way ;  looking
#   Actual: get; diamond; botswana; ask
# --------------------
# Sample 1101:
#   Predicted: customers ;  jewelry ;  need ;  job ;  reacting
#   Actual: customers; jewelry; need; another; one; better; job
# --------------------
# Sample 1102:
#   Predicted: yeah ;  little ;  debate ;  new ;  maybe ;  dramatized ;  progress
#   Actual: geopolitical; complicated; aspect; yeah; progress; overly; maybe
# --------------------
# Sample 1103:
#   Predicted: lockdowns ;  last ;  year ;  think ;  really ;  recovering ;  half
#   Actual: last; lockdowns; back; things; reopened; devastating; pretty
# --------------------
# Sample 1104:
#   Predicted: videos ;  updates ;  world ;  sponsored ;  network
#   Actual: subscribe; predictions; comments; know; let; bringing; like
# --------------------
# Sample 1105:
#   Predicted: said ;  clarify ;  mean
#   Actual: said; mean; clarify
# --------------------
# Sample 1106:
#   Predicted: site ;  holders ;  used ;  meetings ;  london ;  people ;  room
#   Actual: used; site; holders; meetings; room; people; london
# --------------------
# Sample 1107:
#   Predicted: see ;  bracelets ;  tennis ;  popular ;  going
#   Actual: see; bracelets; tennis; classic; years; think; sure
# --------------------
# Sample 1108:
#   Predicted: tool ;  partners ;  using ;  system ;  jeweler
#   Actual: try; terms; lot; using; tool; system; partners
# --------------------
# Sample 1109:
#   Predicted: trend ;  reports ;  india ;  bring ;  yes ;  terms
#   Actual: trend; reports; india; bring; trends; terms; continue
# --------------------
# Sample 1110:
#   Predicted: tv ;  people ;  look ;  stream ;  internet ;  live ;  people
#   Actual: people; watch; tv; less; stream; look; live
# --------------------
# Sample 1111:
#   Predicted: would ;  winston ;  perfect ;  ticket ;  investment ;  say ;  combination
#   Actual: would; winston; ticket; say; perfect; investment; combination
# --------------------
# Sample 1112:
#   Predicted: american ;  well ;  embargo ;  support ;  countries ;  lot ;  motivations
#   Actual: cer; well; african; support; countries; embargo; lot
# --------------------
# Sample 1113:
#   Predicted: open ;  retailers ;  market ;  propose ;  people ;  trading ;  niche
#   Actual: probably; opportunity; open; retailers; gaining; propose; people
# --------------------
# Sample 1114:
#   Predicted: countries ;  increases ;  global ;  modest ;  line
#   Actual: countries; increases; broadly; decade; growth; line; modest
# --------------------
# Sample 1115:
#   Predicted: really ;  answering ;  know ;  calls ;  house ;  hands-on ;  still
#   Actual: answering; know; would; really; calls; day; client
# --------------------
# Sample 1116:
#   Predicted: diamonds ;  forthcoming ;  guidance ;  sure ;  understand
#   Actual: diamonds; explanatory; forthcoming; guidance; understand; advice; sure
# --------------------
# Sample 1117:
#   Predicted: well-deserved ;  thing ;  sleep ;  new ;  aside ;  might ;  podcast
#   Actual: podcast; might; back; thing; sleep; new; life
# --------------------
# Sample 1118:
#   Predicted: canada ;  mean ;  nibia
#   Actual: consumer; care; additional; namibia; mean; canada
# --------------------
# Sample 1119:
#   Predicted: podcast ;  rappaport ;  fact ;  world ;  wanted ;  start ;  cut
#   Actual: maybe; world; wanted; bit; clear; cut; rappaport
# --------------------
# Sample 1120:
#   Predicted: stone ;  figure ;  right ;  today ;  scanning
#   Actual: stone; yonker; let; go; back; today; stones
# --------------------
# Sample 1121:
#   Predicted: week ;  watching ;  thanks ;  rest
#   Actual: week; watching; thanks; rest; enjoy
# --------------------
# Sample 1122:
#   Predicted: story ;  fit ;  something ;  ongoing ;  sure
#   Actual: still; something; ongoing; sure; stories; dealing; story
# --------------------
# Sample 1123:
#   Predicted: store ;  took ;  walked ;  sidearm ;  never ;  owner
#   Actual: store; woody; decided; done; keep; never; owner
# --------------------
# Sample 1124:
#   Predicted: jewelers ;  margins ;  addicted ;  times ;  mean ;  making
#   Actual: jewelers; margins; addicted; times; six; mean; margin
# --------------------
# Sample 1125:
#   Predicted: think ;  break ;  really ;  bridal ;  might ;  sort ;  make
#   Actual: break; bridal; really; scene; rest; seeds; set
# --------------------
# Sample 1126:
#   Predicted: areas ;  supply ;  many ;  enough ;  demand ;  revivals ;  industry
#   Actual: areas; demand; many; enough; supply; four; usually
# --------------------
# Sample 1127:
#   Predicted: way ;  unnatural ;  real ;  kind ;  identity ;  stupid ;  industry
#   Actual: way; unnatural; real; stupid; kind; identity; crisis
# --------------------
# Sample 1128:
#   Predicted: rappaport ;  diamond ;  follow ;  get ;  future ;  podcast ;  visit
#   Actual: rappaport; follow; discussion; diamond; get; future; subscribe
# --------------------
# Sample 1129:
#   Predicted: women ;  wow ;  like ;  older ;  made
#   Actual: women; wow; like; empowering; young; older; mentioned
# --------------------
# Sample 1130:
#   Predicted: maybe ;  go ;  wear ;  okay ;  admit ;  diamonds ;  okay
#   Actual: go; maybe; wear; diamonds; embrace; admit; majority
# --------------------
# Sample 1131:
#   Predicted: think ;  industry ;  change ;  massive ;  preference ;  shift ;  consumer
#   Actual: think; change; industry; preference; massive; business; put
# --------------------
# Sample 1132:
#   Predicted: strong ;  finance ;  happened ;  would ;  sanctions ;  war ;  knew
#   Actual: happened; finance; strong; would; turnover; sanctions; effect
# --------------------
# Sample 1133:
#   Predicted: like ;  keep ;  shifts ;  mind ;  really ;  think ;  mind
#   Actual: keep; shifts; also; like; think; really; mind
# --------------------
# Sample 1134:
#   Predicted: diamonds ;  antwerp ;  people ;  respect ;  would ;  like
#   Actual: antwerp; diamonds; respect; people; sealed; illusion; would
# --------------------
# Sample 1135:
#   Predicted: business ;  remember ;  bourse ;  essence ;  trust ;  people ;  happy
#   Actual: business; essence; remember; bourse; york; trust; people
# --------------------
# Sample 1136:
#   Predicted: values ;  visionary ;  many ;  training ;  quality
#   Actual: training; skills; quality; produced; pieces; visionary; values
# --------------------
# Sample 1137:
#   Predicted: custom ;  educate ;  help ;  pick ;  setting ;  diamond ;  create
#   Actual: help; setting; create; custom; pick; diamond; educate
# --------------------
# Sample 1138:
#   Predicted: sold ;  well ;  second ;  site ;  prices
#   Actual: sold; well; volume; taken; site; seem; second
# --------------------
# Sample 1139:
#   Predicted: would ;  say ;  mean ;  burling ;  fine ;  one ;  tenor
#   Actual: would; say; mean; tenor; one; like; put
# --------------------
# Sample 1140:
#   Predicted: within ;  trade ;  point ;  contention
#   Actual: presenting; option; makes; difference; big; within; trade
# --------------------

# %% [markdown]
# One Sample text is passed to perform sentiment analysis and trends extraction by finetuned model.

# %%
def analyze_text(input_text):
    # Sentiment analysis
    sentiment_inputs = sentiment_tokenizer(input_text, return_tensors="pt", truncation=True, padding=True)
    sentiment_outputs = sentiment_model(**sentiment_inputs)
    sentiment = "positive" if torch.argmax(sentiment_outputs.logits) == 1 else "negative"

    # Trends extraction
    trends_inputs = trends_tokenizer(f"extract keyphrases: {input_text}", return_tensors="pt", truncation=True, padding=True)

    # Move input tensors to the same device as the model
    trends_inputs = trends_inputs.to(trends_model.device)
    trends_outputs = trends_model.generate(trends_inputs.input_ids, max_length=50, num_beams=5, early_stopping=True)
    trends = trends_tokenizer.decode(trends_outputs[0], skip_special_tokens=True)

    return sentiment, trends

# Test combined model
test_sentence = "Lab-grown diamonds are revolutionizing the diamond industry with ethical practices."
result_sentiment, result_trends = analyze_text(test_sentence)

print(f"Sentiment: {result_sentiment}")
print(f"Trends: {result_trends}")
# Out:
# Sentiment: positive
# Trends: diamond ;  practices ;  industry ;  revolutionizing ;  ethical ;  lab-grown

# %% [markdown]
# The model is evaluated on different metrics based on predicted and actual trends saved in finteuned_samples_generated_trends.txt file.

# %%
#!pip install rouge-score

from sklearn.metrics import precision_score, recall_score, f1_score
from rouge_score import rouge_scorer

# File path
file_path = "/content/finteuned_samples_generated_trends.txt"

# Initialize variables
predicted_list = []
actual_list = []

# Parse the file
with open(file_path, "r") as f:
    for line in f:
        if line.startswith("  Predicted:"):
            predicted = line.strip().split(":")[1].strip().split("; ")
            predicted_list.append(predicted)
        elif line.startswith("  Actual:"):
            actual = line.strip().split(":")[1].strip().split("; ")
            actual_list.append(actual)

def mean_reciprocal_rank(predicted, actual):
    mrr_scores = []
    for pred, act in zip(predicted, actual):
        ranks = [i + 1 for i, p in enumerate(pred) if p in act]
        mrr_scores.append(1 / ranks[0] if ranks else 0)
    return sum(mrr_scores) / len(mrr_scores)

def precision_at_k(predicted, actual, k=5):
    precision_scores = []
    for pred, act in zip(predicted, actual):
        pred_top_k = pred[:k]
        tp = sum(1 for p in pred_top_k if p in act)
        precision_scores.append(tp / k)
    return sum(precision_scores) / len(precision_scores)

def recall_at_k(predicted, actual, k=5):
    recall_scores = []
    for pred, act in zip(predicted, actual):
        pred_top_k = pred[:k]
        tp = sum(1 for p in pred_top_k if p in act)
        recall_scores.append(tp / len(act) if act else 0)
    return sum(recall_scores) / len(recall_scores)

def f1_at_k(predicted, actual, k=5):
    precision = precision_at_k(predicted, actual, k)
    recall = recall_at_k(predicted, actual, k)
    if precision + recall == 0:
        return 0
    return 2 * (precision * recall) / (precision + recall)

# Helper function to flatten and get unique elements
def flatten_and_unique(lst):
    return list(set([item.strip().lower() for sublist in lst for item in sublist]))

# Flatten and deduplicate
flat_predicted = flatten_and_unique(predicted_list)
flat_actual = flatten_and_unique(actual_list)

# Compute ROUGE metrics
rouge_scorer_obj = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
rouge_scores = [rouge_scorer_obj.score(" ".join(pred), " ".join(act))
                for pred, act in zip(predicted_list, actual_list)]

# Compute average ROUGE scores
avg_rouge1 = sum([score['rouge1'].fmeasure for score in rouge_scores]) / len(rouge_scores)
avg_rouge2 = sum([score['rouge2'].fmeasure for score in rouge_scores]) / len(rouge_scores)
avg_rougeL = sum([score['rougeL'].fmeasure for score in rouge_scores]) / len(rouge_scores)

print(f"Length of y_pred: {len(flat_predicted)}")
print(f"Length of y_true: {len(flat_actual)}")

min_length = min(len(flat_predicted), len(flat_actual))
flat_predicted = flat_predicted[:min_length]
flat_actual = flat_actual[:min_length]

# Evaluate Metrics
mrr = mean_reciprocal_rank(flat_predicted, flat_actual)
precision_k = precision_at_k(flat_predicted, flat_actual, k=5)
recall_k = recall_at_k(flat_predicted, flat_actual, k=5)
f1_k = f1_at_k(flat_predicted, flat_actual, k=5)

# Display metrics
print(f"Mean Reciprocal Rank (MRR): {mrr:.4f}")
print(f"Precision@k: {precision_k:.4f}")
print(f"Recall@k: {recall_k:.4f}")
print(f"F1@k: {f1_k:.4f}")
print(f"Average ROUGE-1: {avg_rouge1:.4f}")
print(f"Average ROUGE-2: {avg_rouge2:.4f}")
print(f"Average ROUGE-L: {avg_rougeL:.4f}")
# Out:
# Length of y_pred: 2048
# Length of y_true: 2431
# Mean Reciprocal Rank (MRR): 0.5128
# Precision@k: 0.3332
# Recall@k: 0.2495
# F1@k: 0.2854
# Average ROUGE-1: 0.5835
# Average ROUGE-2: 0.1395
# Average ROUGE-L: 0.4343
